# %%
import numpy as np
import featuretools as ft
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
import warnings
warnings.filterwarnings("ignore")

# %%
train_df = pd.read_csv('input/train.csv', na_values=['NAN','NA','NaN','na','nan'])
test_df = pd.read_csv('input/test.csv', na_values=['NAN','NA','NaN','na','nan'])
X_all = pd.read_csv('input/X_all.csv', na_values=['NAN','NA','NaN','na','nan'])
X = pd.read_csv('input/X.csv', na_values=['NAN','NA','NaN','na','nan'])
X_test = pd.read_csv('input/X_test.csv', na_values=['NAN','NA','NaN','na','nan'])

# %%
cols = X.columns.values
cols_num = list(X_all.select_dtypes(include=['int64','float64']).columns)
cols_cat = list(X_all.select_dtypes(include=['object']).columns)

# %%
X.fillna(X.median(), inplace=True)
y.fillna(0, inplace=True)

# %%
train_df['OC'][train_df['OC'] == 'open'] = 0
train_df['OC'][train_df['OC'] == ' close'] = 1

# %%
train_df['OC'].value_counts()
# Out:
# 0    286
# 1     15
# Name: OC, dtype: int64

# %%
imbalanced_pos_ratio = train_df['OC'].value_counts()[1]/train_df['OC'].value_counts()[0]
imbalanced_pos_ratio
# Out:
# 0.05244755244755245

# %%
y = train_df['OC']
X_id = train_df['inst_id']
X_test_id = test_df['inst_id']

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier(class_weights=[1,1/imbalanced_pos_ratio],
                           loss_function='Logloss', logging_level='Silent',
                           task_type='GPU', boosting_type='Plain', bootstrap_type='Bernoulli')

# %%
model.fit(X, y)
preds_class = model.predict(X_test)
preds_proba = model.predict_proba(X_test)
preds_proba[:,1]
# Out:
# array([0.00408123, 0.33128521, 0.05913383, 0.00770652, 0.21381515,
#        0.02458065, 0.05649086, 0.09580576, 0.1380055 , 0.06184026,
#        0.0082946 , 0.03695833, 0.00787514, 0.00474842, 0.00863804,
#        0.08912987, 0.09155763, 0.45556704, 0.06992758, 0.02963349,
#        0.2044366 , 0.09464936, 0.7914983 , 0.03290212, 0.00337411,
#        0.03024739, 0.00585179, 0.0322947 , 0.01323549, 0.08774752,
#        0.02956977, 0.00336785, 0.01000765, 0.00811486, 0.0155715 ,
#        0.00802359, 0.00839108, 0.00640518, 0.00327837, 0.00642084,
#        0.07488033, 0.00894786, 0.00890864, 0.0169063 , 0.10201278,
#        0.10726218, 0.85940602, 0.00518868, 0.01423769, 0.00468961,
#        0.13650379, 0.03393426, 0.67684209, 0.120447  , 0.14326794,
#        0.1110973 , 0.00940531, 0.016318  , 0.03597127, 0.01676867,
#        0.03482678, 0.07428103, 0.02734732, 0.33015677, 0.08182354,
#        0.01087594, 0.70630303, 0.05337437, 0.00762487, 0.05066731,
#        0.01011525, 0.13324898, 0.00374164, 0.02045917, 0.00438431,
#        0.00948597, 0.00368982, 0.0196686 , 0.01364384, 0.00714193,
#        0.00314886, 0.00569244, 0.69760602, 0.00922007, 0.16777993,
#        0.02354768, 0.13766157, 0.01001393, 0.56115475, 0.02683891,
#        0.00487114, 0.01853357, 0.00213997, 0.02624247, 0.14325957,
#        0.02829795, 0.29537729, 0.21757894, 0.55086713, 0.14220076,
#        0.05351199, 0.00445039, 0.02417973, 0.00348491, 0.28508035,
#        0.00286997, 0.0184009 , 0.00213721, 0.06173107, 0.01066105,
#        0.08162335, 0.02463548, 0.08674996, 0.57930111, 0.08919212,
#        0.00684799, 0.00797189, 0.05632158, 0.00490374, 0.00367003,
#        0.00660608, 0.00332345, 0.01835971, 0.0291861 , 0.02846305,
#        0.0125164 , 0.01119374])

# %%
feature_importance = pd.DataFrame()
feature_importance['feature'] = cols
feature_importance['value'] = min_max_scaler.fit_transform(model.feature_importances_.reshape(-1, 1))

# %%
feature_importance.sort_values(by='value', ascending=False)
# Out:
#                                     feature     value
# 933                           employee1_enc  1.000000
# 935                         ownerChange_enc  0.503489
# 934                           employee2_enc  0.442972
# 113         DIFF(shortLoan1 by ownerChange)  0.223277
# 154              DIFF(bedCount by instkind)  0.169799
# 930                                sido_enc  0.169014
# 152          DIFF(longLoan2 by ownerChange)  0.097562
# 250          DIFF(liquidAsset2 by instkind)  0.082055
# 206                 DIFF(ctax2 by instkind)  0.077936
# 184           DIFF(inventoryAsset2 by sido)  0.066715
# 146           DIFF(quickAsset2 by instkind)  0.064826
# 251            DIFF(shortLoan1 by instkind)  0.049681
# 147                 DIFF(netAsset1 by sido)  0.049561
# 133       DIFF(inventoryAsset2 by instkind)  0.047599
# 262           DIFF(inventoryAsset1 by sido)  0.045728
# 198        DIFF(OnonCAsset2 by ownerChange)  0.042402
# 199                      DIFF(noe1 by sido)  0.041248
# 789              city.STD(clients.bedCount)  0.038856
# 131           DIFF(OnonCAsset2 by instkind)  0.038681
# 796             city.MEAN(clients.bedCount)  0.031823
# 83                                    debt1  0.031538
# 202                   DIFF(sgg by instkind)  0.029217
# 254             DIFF(interest1 by instkind)  0.027682
# 127                      DIFF(noi2 by sido)  0.026168
# 924         city.MEDIAN(clients.salescost1)  0.025698
# 813           city.MEAN(clients.salescost2)  0.025032
# 108             DIFF(tanAsset2 by instkind)  0.024883
# 545     city.MEDIAN(clients.NCLiabilities2)  0.024613
# 637            city.STD(clients.salescost1)  0.024564
# 163                      DIFF(noe2 by sido)  0.024524
# ..                                      ...       ...
# 503          city.MEAN(clients.quickAsset2)  0.000000
# 506    kind.MODE(clients.employee2) = 901.0  0.000000
# 507     kind.MODE(clients.employee2) = 15.0  0.000000
# 508     kind.MODE(clients.employee2) = 10.0  0.000000
# 509      kind.MODE(clients.employee2) = 409  0.000000
# 510    kind.MODE(clients.employee2) = 109.0  0.000000
# 511  kind.MODE(clients.employee2) = unknown  0.000000
# 515                     kind.COUNT(clients)  0.000000
# 516                  kind.SUM(clients.noi1)  0.000000
# 517          kind.SUM(clients.receivableS2)  0.000000
# 494              city.SUM(clients.surplus2)  0.000000
# 488          change.SUM(clients.shortLoan1)  0.000000
# 455           change.SUM(clients.longLoan2)  0.000000
# 486                 kind.STD(clients.debt1)  0.000000
# 456     change.MEDIAN(clients.receivableL2)  0.000000
# 460                kind.MEAN(clients.ctax1)  0.000000
# 461     change.MEDIAN(clients.liquidAsset1)  0.000000
# 464                change.SUM(clients.sga1)  0.000000
# 465             kind.STD(clients.interest2)  0.000000
# 467         change.SUM(clients.quickAsset1)  0.000000
# 469               kind.SUM(clients.profit1)  0.000000
# 471    kind.SUM(clients.liquidLiabilities2)  0.000000
# 472              kind.STD(clients.surplus2)  0.000000
# 474           change.SUM(clients.tanAsset1)  0.000000
# 475           kind.STD(clients.quickAsset2)  0.000000
# 477        change.MEDIAN(clients.longLoan2)  0.000000
# 479           kind.STD(clients.quickAsset1)  0.000000
# 482       city.SUM(clients.inventoryAsset2)  0.000000
# 483      change.SUM(clients.NCLiabilities1)  0.000000
# 468            city.MEAN(clients.tanAsset1)  0.000000
#
# [936 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators=500, max_depth=20, random_state=0, n_jobs=8, class_weight='balanced')

# %%
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=20, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=8, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)

# %%
feature_importance2 = pd.DataFrame()
feature_importance2['feature'] = cols
feature_importance2['value'] = min_max_scaler.fit_transform(clf.feature_importances_.reshape(-1, 1))
feature_importance2.sort_values(by='value', ascending=False)
# Out:
#                                     feature     value
# 933                           employee1_enc  1.000000
# 934                           employee2_enc  0.903357
# 930                                sido_enc  0.504630
# 113         DIFF(shortLoan1 by ownerChange)  0.499055
# 935                         ownerChange_enc  0.410934
# 149            DIFF(profit2 by ownerChange)  0.201299
# 198        DIFF(OnonCAsset2 by ownerChange)  0.200832
# 154              DIFF(bedCount by instkind)  0.189897
# 66                               salescost2  0.160925
# 186               DIFF(noe1 by ownerChange)  0.158984
# 93                          inventoryAsset2  0.156569
# 94         DIFF(OnonCAsset1 by ownerChange)  0.152418
# 35                               salescost1  0.142994
# 924         city.MEDIAN(clients.salescost1)  0.137270
# 108             DIFF(tanAsset2 by instkind)  0.136135
# 789              city.STD(clients.bedCount)  0.134569
# 513        city.MEDIAN(clients.quickAsset1)  0.133713
# 145            DIFF(salescost1 by instkind)  0.133369
# 904       city.MEDIAN(clients.liquidAsset1)  0.131717
# 187        DIFF(NCLiabilities2 by instkind)  0.130762
# 156            DIFF(nonCAsset2 by instkind)  0.128520
# 229                DIFF(sgg by ownerChange)  0.121688
# 99         DIFF(quickAsset2 by ownerChange)  0.121652
# 246                  DIFF(noi2 by instkind)  0.117220
# 202                   DIFF(sgg by instkind)  0.115609
# 167               DIFF(noe2 by ownerChange)  0.114477
# 260            DIFF(shortLoan2 by instkind)  0.113137
# 251            DIFF(shortLoan1 by instkind)  0.112584
# 192             DIFF(netAsset2 by instkind)  0.111937
# 53                                tanAsset2  0.111570
# ..                                      ...       ...
# 640          city.SUM(clients.receivableL2)  0.000000
# 341            kind.STD(clients.shortLoan1)  0.000000
# 374          change.MEAN(clients.interest2)  0.000000
# 379                  kind.SUM(clients.sga2)  0.000000
# 797          change.MEDIAN(clients.salary1)  0.000000
# 380  change.MEDIAN(clients.inventoryAsset2)  0.000000
# 419        change.SUM(clients.liquidAsset1)  0.000000
# 511  kind.MODE(clients.employee2) = unknown  0.000000
# 415  change.STD(clients.liquidLiabilities1)  0.000000
# 701          change.MEAN(clients.netAsset1)  0.000000
# 777     city.MODE(clients.employee1) = 42.0  0.000000
# 512            kind.MEAN(clients.netAsset1)  0.000000
# 618               change.STD(clients.ctax1)  0.000000
# 410        change.MEAN(clients.quickAsset1)  0.000000
# 515                     kind.COUNT(clients)  0.000000
# 659           change.SUM(clients.netAsset2)  0.000000
# 783    city.MODE(clients.employee1) = 342.0  0.000000
# 409  change.MEDIAN(clients.inventoryAsset1)  0.000000
# 785     city.MODE(clients.employee1) = 70.0  0.000000
# 786    city.MODE(clients.employee1) = 132.0  0.000000
# 407           change.SUM(clients.tanAsset2)  0.000000
# 788               change.MEAN(clients.noe2)  0.000000
# 406      change.MEDIAN(clients.OnonCAsset1)  0.000000
# 405       kind.SUM(clients.inventoryAsset1)  0.000000
# 583       kind.MEDIAN(clients.receivableL1)  0.000000
# 599        change.STD(clients.liquidAsset2)  0.000000
# 23                         employee1 = 79.0  0.000000
# 794                  kind.SUM(clients.noi2)  0.000000
# 393              kind.SUM(clients.surplus2)  0.000000
# 532           change.MEAN(clients.bedCount)  0.000000
#
# [936 rows x 2 columns]

# %%
import lightgbm as lgb

# %%
clf = lgb.LGBMClassifier(
        device = "gpu",
        gpu_platform_id = 0,
        gpu_device_id = 1,
        n_estimators=500,
        learning_rate=0.01,
        is_unbalance=True,
        metric='auc',
        boosting_type='gbdt',
        num_leaves=14,
        colsample_bytree=0.757,
        feature_fraction=0.746,
        verbose=2,
    )

# %%
clf.fit(X,y.astype('int'),verbose=True)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None,
#         colsample_bytree=0.757, device='gpu', feature_fraction=0.746,
#         gpu_device_id=1, gpu_platform_id=0, importance_type='split',
#         is_unbalance=True, learning_rate=0.01, max_depth=-1, metric='auc',
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=500, n_jobs=-1, num_leaves=14, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0,
#         verbose=2)

# %%
feature_importance3 = pd.DataFrame()
feature_importance3['feature'] = cols
feature_importance3['value'] = min_max_scaler.fit_transform(clf.feature_importances_.reshape(-1, 1))
feature_importance3.sort_values(by='value', ascending=False)
# Out:
#                                   feature     value
# 930                              sido_enc  1.000000
# 933                         employee1_enc  0.888283
# 934                         employee2_enc  0.773842
# 113       DIFF(shortLoan1 by ownerChange)  0.555858
# 67                               bedCount  0.354223
# 91                     liquidLiabilities2  0.348774
# 186             DIFF(noe1 by ownerChange)  0.324251
# 615          city.STD(clients.shortLoan1)  0.302452
# 93                        inventoryAsset2  0.294278
# 149          DIFF(profit2 by ownerChange)  0.237057
# 935                       ownerChange_enc  0.234332
# 10                     liquidLiabilities1  0.215259
# 169         DIFF(bedCount by ownerChange)  0.215259
# 154            DIFF(bedCount by instkind)  0.201635
# 163                    DIFF(noe2 by sido)  0.201635
# 131         DIFF(OnonCAsset2 by instkind)  0.198910
# 92                                    sgg  0.196185
# 83                                  debt1  0.196185
# 12                        inventoryAsset1  0.182561
# 229              DIFF(sgg by ownerChange)  0.171662
# 5                               longLoan1  0.158038
# 104             DIFF(OnonCAsset2 by sido)  0.155313
# 152        DIFF(longLoan2 by ownerChange)  0.141689
# 251          DIFF(shortLoan1 by instkind)  0.128065
# 165                DIFF(bedCount by sido)  0.122616
# 1                               tanAsset1  0.114441
# 51                                salary1  0.106267
# 247     DIFF(receivableS1 by ownerChange)  0.106267
# 232                   DIFF(ctax2 by sido)  0.106267
# 121       DIFF(salescost1 by ownerChange)  0.103542
# ..                                    ...       ...
# 492          change.STD(clients.surplus1)  0.000000
# 493        kind.MEDIAN(clients.netAsset1)  0.000000
# 494            city.SUM(clients.surplus2)  0.000000
# 495          kind.SUM(clients.shortLoan2)  0.000000
# 496              change.SUM(clients.noe1)  0.000000
# 497               change.SUM(clients.sgg)  0.000000
# 498           kind.SUM(clients.tanAsset2)  0.000000
# 499     change.MEAN(clients.receivableL1)  0.000000
# 502     city.MEDIAN(clients.receivableL2)  0.000000
# 483    change.SUM(clients.NCLiabilities1)  0.000000
# 482     city.SUM(clients.inventoryAsset2)  0.000000
# 50                     instkind = unknown  0.000000
# 470          kind.MEAN(clients.longLoan1)  0.000000
# 462        city.STD(clients.receivableS2)  0.000000
# 463            kind.MEDIAN(clients.debt1)  0.000000
# 464              change.SUM(clients.sga1)  0.000000
# 465           kind.STD(clients.interest2)  0.000000
# 467       change.SUM(clients.quickAsset1)  0.000000
# 56                       sido = gyeongbuk  0.000000
# 469             kind.SUM(clients.profit1)  0.000000
# 471  kind.SUM(clients.liquidLiabilities2)  0.000000
# 480        city.MEDIAN(clients.tanAsset1)  0.000000
# 55                        sido = gyeonggi  0.000000
# 474         change.SUM(clients.tanAsset1)  0.000000
# 475         kind.STD(clients.quickAsset2)  0.000000
# 476             change.SUM(clients.debt1)  0.000000
# 477      change.MEDIAN(clients.longLoan2)  0.000000
# 478          kind.STD(clients.shortLoan2)  0.000000
# 479         kind.STD(clients.quickAsset1)  0.000000
# 468          city.MEAN(clients.tanAsset1)  0.000000
#
# [936 rows x 2 columns]

# %%
from xgboost.sklearn import XGBClassifier

# %%
xgb = XGBClassifier(
         learning_rate= 0.1,
         objective= 'binary:logistic',
         tree_method='gpu_exact',
         predictor='gpu_predictor',
         scale_pos_weight=int(1/imbalanced_pos_ratio),
         seed=42)

# %%
xgb.fit(X,y.astype('int'),verbose=True)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic',
#        predictor='gpu_predictor', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=19, seed=42, silent=True,
#        subsample=1, tree_method='gpu_exact')

# %%
feature_importance4 = pd.DataFrame()
feature_importance4['feature'] = cols
feature_importance4['value'] = min_max_scaler.fit_transform(xgb.feature_importances_.reshape(-1, 1))

# %%
feature_importance4.sort_values(by='value', ascending=False)
# Out:
#                                      feature     value
# 0                                       noi1  1.000000
# 933                            employee1_enc  0.483516
# 935                          ownerChange_enc  0.274725
# 113          DIFF(shortLoan1 by ownerChange)  0.252747
# 934                            employee2_enc  0.208791
# 84                               OnonCAsset1  0.197802
# 131            DIFF(OnonCAsset2 by instkind)  0.186813
# 201            DIFF(OnonCAsset1 by instkind)  0.175824
# 229                 DIFF(sgg by ownerChange)  0.175824
# 930                                 sido_enc  0.164835
# 149             DIFF(profit2 by ownerChange)  0.153846
# 108              DIFF(tanAsset2 by instkind)  0.131868
# 462           city.STD(clients.receivableS2)  0.131868
# 545      city.MEDIAN(clients.NCLiabilities2)  0.098901
# 408               city.STD(clients.surplus2)  0.087912
# 94          DIFF(OnonCAsset1 by ownerChange)  0.087912
# 93                           inventoryAsset2  0.087912
# 169            DIFF(bedCount by ownerChange)  0.087912
# 202                    DIFF(sgg by instkind)  0.076923
# 12                           inventoryAsset1  0.076923
# 904        city.MEDIAN(clients.liquidAsset1)  0.076923
# 191                DIFF(salary2 by instkind)  0.065934
# 152           DIFF(longLoan2 by ownerChange)  0.065934
# 237               DIFF(liquidAsset2 by sido)  0.065934
# 321                city.STD(clients.salary2)  0.054945
# 177                    WEEK(openDate) = 49.0  0.054945
# 91                        liquidLiabilities2  0.054945
# 145             DIFF(salescost1 by instkind)  0.054945
# 51                                   salary1  0.054945
# 186                DIFF(noe1 by ownerChange)  0.054945
# ..                                       ...       ...
# 424               kind.MEAN(clients.salary2)  0.000000
# 425           city.MEDIAN(clients.netAsset2)  0.000000
# 426            kind.SUM(clients.OnonCAsset2)  0.000000
# 427           kind.MEAN(clients.quickAsset2)  0.000000
# 428  change.MEAN(clients.liquidLiabilities1)  0.000000
# 404                change.MEAN(clients.noi1)  0.000000
# 403      change.STD(clients.inventoryAsset2)  0.000000
# 402               kind.STD(clients.revenue1)  0.000000
# 389                   city.STD(clients.sga2)  0.000000
# 379                   kind.SUM(clients.sga2)  0.000000
# 380   change.MEDIAN(clients.inventoryAsset2)  0.000000
# 381                city.STD(clients.profit2)  0.000000
# 382             city.SUM(clients.shortLoan1)  0.000000
# 384           kind.MEAN(clients.OnonCAsset1)  0.000000
# 385             city.MEAN(clients.netAsset1)  0.000000
# 386            kind.MEAN(clients.salescost2)  0.000000
# 387                  city.MEAN(clients.noe2)  0.000000
# 388     city.SUM(clients.liquidLiabilities1)  0.000000
# 390           kind.SUM(clients.receivableL2)  0.000000
# 400             city.MEAN(clients.longLoan1)  0.000000
# 391                  kind.MEAN(clients.noe1)  0.000000
# 392        kind.MEAN(clients.NCLiabilities1)  0.000000
# 393               kind.SUM(clients.surplus2)  0.000000
# 394          city.MEDIAN(clients.salescost2)  0.000000
# 395           kind.MEDIAN(clients.longLoan2)  0.000000
# 396                 change.STD(clients.sga2)  0.000000
# 397              kind.MEAN(clients.bedCount)  0.000000
# 398            city.MEAN(clients.nonCAsset2)  0.000000
# 399            city.MEDIAN(clients.revenue2)  0.000000
# 468             city.MEAN(clients.tanAsset1)  0.000000
#
# [936 rows x 2 columns]

# %%
ft_importance_total = pd.DataFrame()
ft_importance_total['feature'] = cols
ft_importance_total['value'] = (feature_importance['value']+feature_importance2['value']+feature_importance3['value']+feature_importance4['value'])/4

# %%
ft_importance_total[ft_importance_total.value >= np.percentile(ft_importance_total.value,80)].sort_values(by='value', ascending=False)
# Out:
#                                   feature     value
# 933                         employee1_enc  0.842950
# 934                         employee2_enc  0.582240
# 930                              sido_enc  0.459620
# 113       DIFF(shortLoan1 by ownerChange)  0.382734
# 935                       ownerChange_enc  0.355870
# 0                                    noi1  0.268441
# 149          DIFF(profit2 by ownerChange)  0.148903
# 154            DIFF(bedCount by instkind)  0.145827
# 186             DIFF(noe1 by ownerChange)  0.139725
# 93                        inventoryAsset2  0.136877
# 131         DIFF(OnonCAsset2 by instkind)  0.133073
# 91                     liquidLiabilities2  0.130106
# 67                               bedCount  0.118044
# 229              DIFF(sgg by ownerChange)  0.117704
# 169         DIFF(bedCount by ownerChange)  0.103336
# 152        DIFF(longLoan2 by ownerChange)  0.103229
# 615          city.STD(clients.shortLoan1)  0.091747
# 108           DIFF(tanAsset2 by instkind)  0.091614
# 84                            OnonCAsset1  0.089843
# 94       DIFF(OnonCAsset1 by ownerChange)  0.089019
# 201         DIFF(OnonCAsset1 by instkind)  0.086343
# 10                     liquidLiabilities1  0.084366
# 92                                    sgg  0.083769
# 83                                  debt1  0.079838
# 12                        inventoryAsset1  0.079090
# 251          DIFF(shortLoan1 by instkind)  0.078077
# 163                    DIFF(noe2 by sido)  0.076603
# 789            city.STD(clients.bedCount)  0.072693
# 202                 DIFF(sgg by instkind)  0.071105
# 545   city.MEDIAN(clients.NCLiabilities2)  0.069635
# ..                                    ...       ...
# 674             city.SUM(clients.profit1)  0.019778
# 346               city.MEAN(clients.sga2)  0.019768
# 103         DIFF(revenue2 by ownerChange)  0.019629
# 118               DIFF(debt2 by instkind)  0.019429
# 110             DIFF(noi2 by ownerChange)  0.019371
# 194               DIFF(longLoan1 by sido)  0.019346
# 249      DIFF(NCLiabilities1 by instkind)  0.019228
# 481       city.MEDIAN(clients.shortLoan1)  0.019061
# 382          city.SUM(clients.shortLoan1)  0.018934
# 256     DIFF(inventoryAsset1 by instkind)  0.018770
# 210       DIFF(salescost2 by ownerChange)  0.018625
# 223           DIFF(tanAsset1 by instkind)  0.018342
# 69                                   sga2  0.018202
# 366       city.MEDIAN(clients.shortLoan2)  0.018125
# 932                          instkind_enc  0.017984
# 122             DIFF(OnonCAsset1 by sido)  0.017787
# 197               DIFF(tanAsset2 by sido)  0.017583
# 643  city.MEDIAN(clients.inventoryAsset1)  0.017534
# 238            DIFF(ctax1 by ownerChange)  0.017403
# 203       DIFF(shortLoan2 by ownerChange)  0.017377
# 655           city.STD(clients.interest2)  0.017307
# 234              DIFF(salescost2 by sido)  0.017214
# 71                                   noe1  0.017179
# 220  DIFF(inventoryAsset2 by ownerChange)  0.017173
# 355               city.SUM(clients.debt2)  0.017034
# 218               DIFF(netAsset2 by sido)  0.016786
# 580        city.SUM(clients.receivableS1)  0.016768
# 95             DIFF(surplus2 by instkind)  0.016619
# 241              DIFF(shortLoan2 by sido)  0.016578
# 236           DIFF(longLoan1 by instkind)  0.016564
#
# [188 rows x 2 columns]

# %%
ft_importance_total.to_csv('input/ft_importance_total.csv')
